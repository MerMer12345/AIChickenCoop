# %% [markdown]
# Generate Evaluation Data:

# %%
from ultralytics import YOLO

model = YOLO('../Training/trained_models/yolo12x/weights/best.pt')
model.val(data='../ImgLabelling/ValidationDataset/data.yaml', split='val')
# Out:
# Ultralytics 8.3.105  Python-3.12.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# YOLOv12x summary (fused): 283 layers, 59,044,499 parameters, 0 gradients, 198.5 GFLOPs
# val: Scanning C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\ValidationDataset\valid\labels... 91 images, 0 backgrounds, 0 corrupt: 100%|██████████| 91/91 [00:00<00:00, 419.62it/s]
# val: WARNING  C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\ValidationDataset\valid\images\Validation2-00002.jpg: 1 duplicate labels removed
# val: New cache created: C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\ValidationDataset\valid\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:02<00:00,  2.06it/s]
#                    all         91        277      0.903      0.842      0.881      0.761
# Speed: 0.3ms preprocess, 26.4ms inference, 0.0ms loss, 1.5ms postprocess per image
# ...

# %%
from ultralytics import YOLO

model = YOLO('../Training/trained_models/yolov8x/weights/best.pt')
model.val(data='../ImgLabelling/ValidationDataset/data.yaml', split='val')
# Out:
# Ultralytics 8.3.105  Python-3.12.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# Model summary (fused): 112 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\ValidationDataset\valid\labels.cache... 91 images, 0 backgrounds, 0 corrupt: 100%|██████████| 91/91 [00:00<?, ?it/s]
# val: WARNING  C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\ValidationDataset\valid\images\Validation2-00002.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:02<00:00,  2.21it/s]
#                    all         91        277      0.865      0.811       0.85      0.772
# Speed: 0.4ms preprocess, 23.6ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to C:\Users\Merle\PycharmProjects\ChickenCam\runs\detect\val3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ...
