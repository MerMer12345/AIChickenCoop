# %%
# !nvidia-smi

# !nvcc --version
# Out:
# Thu Apr 10 16:46:12 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.61                 Driver Version: 572.61         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2070      WDDM  |   00000000:07:00.0  On |                  N/A |
# |  0%   54C    P2             58W /  215W |    2311MiB /   8192MiB |     23%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch, gc
gc.collect()
torch.cuda.empty_cache()

# %%
import torch, gc

print(torch.cuda.is_available())  # Should return True
print(torch.cuda.current_device())  # Should GPU id
print(torch.cuda.get_device_name(0))  # Check if it's real GPU
#if the thers an error that says cuda isnt available uninstall torch and reinstall like ths:pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118 --no-cache-dir
# Out:
# True
# 0
# NVIDIA GeForce RTX 2070

# %%
import torch
from ultralytics import YOLO

# List of model types you want to train
models = ['yolo12x', 'yolov11x']

# Path to your dataset YAML
data_yaml = '../ImgLabelling/TestDataset/data.yaml'

# Output folder to store all models
output_dir = 'trained_models'


# Train each model
for model_type in models:
    print(f"Training {model_type}...")
    print(torch.cuda.memory_summary())
    torch.cuda.empty_cache()
    gc.collect()
    model = YOLO(f'{model_type}.pt')  # Load pretrained model
    model.train(
        data=data_yaml,
        epochs=50,
        imgsz=640,
        batch=8,  # oder sogar 4 oder 2
        project=output_dir,
        name=model_type,
        exist_ok=True
    )
    print(f"{model_type} training complete.\n")

    del model
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# Training yolo12x...
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 3            |        cudaMalloc retries: 4         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   1215 MiB |  21758 MiB |  69625 MiB |  68410 MiB |
# |       from large pool |   1109 MiB |  21546 MiB |  68656 MiB |  67547 MiB |
# |       from small pool |    105 MiB |    254 MiB |    968 MiB |    863 MiB |
# |---------------------------------------------------------------------------|
# | Active memory         |   1215 MiB |  21758 MiB |  69625 MiB |  68410 MiB |
# ...

# %%
from ultralytics import YOLO

# Load a previously trained model
model = YOLO('trained_models/yolov8n/weights/best.pt')

# Recognise on an Image that it has never seen
results = model('test_difficult.png')

# Show results
results[0].show()
# Out:
# image 1/1 C:\Users\Merle\PycharmProjects\AIChickenCoop\Training\test_difficult.png: 640x384 3 birds, 60.8ms
# Speed: 2.1ms preprocess, 60.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
