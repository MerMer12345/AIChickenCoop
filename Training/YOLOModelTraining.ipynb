# %%
import torch

print(torch.cuda.is_available())  # Should return True
print(torch.cuda.current_device())  # Should GPU id
print(torch.cuda.get_device_name(0))  # Check if it's real GPU
#if the thers an error that says cuda isnt available uninstall torch and reinstall like ths:pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118 --no-cache-dir
# Out:
# True
# 0
# NVIDIA GeForce RTX 2070

# %%
from ultralytics import YOLO

# List of model types you want to train
models = ['yolov8x', 'yolo12x', 'yolov11x']

# Path to your dataset YAML
data_yaml = '../ImgLabelling/TestDataset/data.yaml'

# Output folder to store all models
output_dir = 'trained_models'


# Train each model
for model_type in models:
    print(f"Training {model_type}...")
    model = YOLO(f'{model_type}.pt')  # Load pretrained model
    model.train(
        data=data_yaml,
        epochs=50,
        imgsz=640,
        project=output_dir,
        name=model_type,
        exist_ok=True
    )
    print(f"{model_type} training complete.\n")
# Out:
# Training yolov8x...
# Ultralytics 8.3.105  Python-3.12.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# engine\trainer: task=detect, mode=train, model=yolov8x.pt, data=../ImgLabelling/TestDataset/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=trained_models, name=yolov8x, exist_ok=True, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=trained_models\yolov8x
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8718931  ultralytics.nn.modules.head.Detect           [1, [320, 640, 640]]
# Model summary: 209 layers, 68,153,571 parameters, 68,153,555 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Scanning C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\train\labels.cache... 251 images, 2 backgrounds, 0 corrupt: 100%|██████████| 251/251 [00:00<?, ?it/s]
# train: WARNING  C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\train\images\SmallTest5-00088.jpg: 1 duplicate labels removed
# val: Scanning C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\valid\labels.cache... 91 images, 2 backgrounds, 0 corrupt: 100%|██████████| 91/91 [00:00<?, ?it/s]
# val: WARNING  C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\valid\images\SmallTest4-00148.jpg: 1 duplicate labels removed
# val: WARNING  C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\valid\images\SmallTest5-00066.jpg: 1 duplicate labels removed
# Plotting labels to trained_models\yolov8x\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to trained_models\yolov8x
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      12.1G     0.7171      3.033      1.174         70        640: 100%|██████████| 16/16 [07:36<00:00, 28.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:49<00:00, 16.39s/it]
#                    all         91        218      0.231      0.789      0.203       0.12
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      12.3G     0.5742     0.8384      1.013         78        640: 100%|██████████| 16/16 [05:01<00:00, 18.87s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:46<00:00, 15.54s/it]
#                    all         91        218     0.0023      0.266    0.00142   0.000643
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      12.6G     0.6359     0.7112      1.061         80        640: 100%|██████████| 16/16 [14:36<00:00, 54.75s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [02:19<00:00, 46.40s/it]
#                    all         91        218          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      12.7G     0.6192     0.6176      1.041         68        640: 100%|██████████| 16/16 [05:44<00:00, 21.55s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:52<00:00, 17.47s/it]
#                    all         91        218   0.000542    0.00459   0.000273   5.46e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      12.7G     0.5889     0.5574      1.006         62        640: 100%|██████████| 16/16 [18:03<00:00, 67.71s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [01:53<00:00, 37.93s/it]
#                    all         91        218     0.0117     0.0963    0.00641    0.00228
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      12.6G     0.5554     0.5339     0.9974         76        640: 100%|██████████| 16/16 [04:16<00:00, 16.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:27<00:00,  9.32s/it]
#                    all         91        218     0.0115     0.0688    0.00436    0.00181
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      12.3G     0.5487     0.5108     0.9847         73        640: 100%|██████████| 16/16 [03:22<00:00, 12.65s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:28<00:00,  9.49s/it]
#                    all         91        218       0.16      0.528      0.205     0.0971
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      12.3G      0.572     0.4778      0.995         72        640: 100%|██████████| 16/16 [03:07<00:00, 11.71s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:23<00:00,  7
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      12.3G     0.1687      0.149     0.8119         34        640: 100%|██████████| 16/16 [03:22<00:00, 12.67s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:28<00:00,  9.60s/it]
#                    all         91        218      0.906      0.908      0.912      0.888
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      12.3G     0.1751     0.1517     0.8187         31        640: 100%|██████████| 16/16 [03:26<00:00, 12.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:28<00:00,  9.37s/it]
#                    all         91        218      0.904      0.908      0.915      0.892
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      12.3G     0.1674     0.1446     0.8178         34        640: 100%|██████████| 16/16 [03:20<00:00, 12.53s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:28<00:00,  9.57s/it]
#                    all         91        218      0.912      0.904      0.916      0.897
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      12.3G     0.1587     0.1378     0.7993         37        640: 100%|██████████| 16/16 [03:25<00:00, 12.85s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:28<00:00,  9.48s/it]
#                    all         91        218      0.908      0.904      0.917        0.9
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      12.3G     0.1482      0.129     0.7852         31        640: 100%|██████████| 16/16 [03:14<00:00, 12.13s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:28<00:00,  9.45s/it]
#                    all         91        218       0.92      0.899      0.917      0.898
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      12.3G     0.1518     0.1267     0.8128         33        640: 100%|██████████| 16/16 [03:00<00:00, 11.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:28<00:00,  9.44s/it]
#                    all         91        218      0.919      0.899      0.919      0.902
# 50 epochs completed in 3.873 hours.
# Optimizer stripped from trained_models\yolov8x\weights\last.pt, 136.7MB
# Optimizer stripped from trained_models\yolov8x\weights\best.pt, 136.7MB
#
# Validating trained_models\yolov8x\weights\best.pt...
# Ultralytics 8.3.105  Python-3.12.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# Model summary (fused): 112 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:02<00:00,  1.08it/s]
#                    all         91        218       0.91      0.899      0.919      0.902
# Speed: 0.3ms preprocess, 25.8ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to trained_models\yolov8x
# yolov8x training complete.
#
# Training yolo12x...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12x.pt to 'yolo12x.pt'...
#  28%|██▊       | 31.9M/114M [00:01<00:04, 18.1MB/s]
#  Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12x.pt...
# Ultralytics 8.3.105  Python-3.12.6 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
# engine\trainer: task=detect, mode=train, model=yolo12x.pt, data=../ImgLabelling/TestDataset/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=trained_models, name=yolo12x, exist_ok=True, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=trained_models\yolo12x
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2784  ultralytics.nn.modules.conv.Conv             [3, 96, 3, 2]
#   1                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   2                  -1  2    389760  ultralytics.nn.modules.block.C3k2            [192, 384, 2, True, 0.25]
#   3                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#   4                  -1  2   1553664  ultralytics.nn.modules.block.C3k2            [384, 768, 2, True, 0.25]
#   5                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   6                  -1  4   9512128  ultralytics.nn.modules.block.A2C2f           [768, 768, 4, True, 4, True, 1.2]
#   7                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#   8                  -1  4   9512128  ultralytics.nn.modules.block.A2C2f           [768, 768, 4, True, 1, True, 1.2]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  2   4727040  ultralytics.nn.modules.block.A2C2f           [1536, 768, 2, False, -1, True, 1.2]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  2   1331328  ultralytics.nn.modules.block.A2C2f           [1536, 384, 2, False, -1, True, 1.2]
#  15                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  2   4579584  ultralytics.nn.modules.block.A2C2f           [1152, 768, 2, False, -1, True, 1.2]
#  18                  -1  1   5309952  ultralytics.nn.modules.conv.Conv             [768, 768, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  2   5612544  ultralytics.nn.modules.block.C3k2            [1536, 768, 2, True]
#  21        [14, 17, 20]  1   3146707  ultralytics.nn.modules.head.Detect           [1, [384, 768, 768]]
# YOLOv12x summary: 488 layers, 59,119,539 parameters, 59,119,523 gradients, 199.8 GFLOPs
#
# Transferred 1239/1245 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Scanning C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\train\labels.cache... 251 images, 2 backgrounds, 0 corrupt: 100%|██████████| 251/251 [00:00<?, ?it/s]
# train: WARNING  C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\train\images\SmallTest5-00088.jpg: 1 duplicate labels removed
# val: Scanning C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\valid\labels.cache... 91 images, 2 backgrounds, 0 corrupt: 100%|██████████| 91/91 [00:00<?, ?it/s]
# val: WARNING  C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\valid\images\SmallTest4-00148.jpg: 1 duplicate labels removed
# val: WARNING  C:\Users\Merle\PycharmProjects\AIChickenCoop\ImgLabelling\TestDataset\valid\images\SmallTest5-00066.jpg: 1 duplicate labels removed
# Plotting labels to trained_models\yolo12x\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 205 weight(decay=0.0), 214 weight(decay=0.0005), 211 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to trained_models\yolo12x
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/16 [00:13<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[4], line 17
#      15 print(f"Training {model_type}...")
#      16 model = YOLO(f'{model_type}.pt')  # Load pretrained model
# ---> 17 model.train(
#      18     data=data_yaml,
#      19     epochs=50,
#      20     imgsz=640,
#      21     project=output_dir,
#      22     name=model_type,
#      23     exist_ok=True
#      24 )
#      25 print(f"{model_type} training complete.\n")
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\engine\model.py:791, in Model.train(self, trainer, **kwargs)
#     788     self.model = self.trainer.model
#     790 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 791 self.trainer.train()
#     792 # Update model and cfg after training
#     793 if RANK in {-1, 0}:
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\engine\trainer.py:211, in BaseTrainer.train(self)
#     208         ddp_cleanup(self, str(file))
#     210 else:
# --> 211     self._do_train(world_size)
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\engine\trainer.py:385, in BaseTrainer._do_train(self, world_size)
#     383 with autocast(self.amp):
#     384     batch = self.preprocess_batch(batch)
# --> 385     loss, self.loss_items = self.model(batch)
#     386     self.loss = loss.sum()
#     387     if RANK != -1:
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\nn\tasks.py:119, in BaseModel.forward(self, x, *args, **kwargs)
#     105 """
#     106 Perform forward pass of the model for either training or inference.
#     107
#    (...)    116     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     117 """
#     118 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 119     return self.loss(x, *args, **kwargs)
#     120 return self.predict(x, *args, **kwargs)
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\nn\tasks.py:298, in BaseModel.loss(self, batch, preds)
#     295 if getattr(self, "criterion", None) is None:
#     296     self.criterion = self.init_criterion()
# --> 298 preds = self.forward(batch["img"]) if preds is None else preds
#     299 return self.criterion(preds, batch)
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\nn\tasks.py:120, in BaseModel.forward(self, x, *args, **kwargs)
#     118 if isinstance(x, dict):  # for cases of training and validating while training.
#     119     return self.loss(x, *args, **kwargs)
# --> 120 return self.predict(x, *args, **kwargs)
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\nn\tasks.py:138, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     136 if augment:
#     137     return self._predict_augment(x)
# --> 138 return self._predict_once(x, profile, visualize, embed)
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\nn\tasks.py:159, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     157 if profile:
#     158     self._profile_one_layer(m, x, dt)
# --> 159 x = m(x)  # run
#     160 y.append(x if m.i in self.save else None)  # save output
#     161 if visualize:
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:1873, in A2C2f.forward(self, x)
#    1863 """
#    1864 Forward pass through A2C2f layer.
#    1865
#    (...)   1870     (torch.Tensor): Output tensor after processing.
#    1871 """
#    1872 y = [self.cv1(x)]
# -> 1873 y.extend(m(y[-1]) for m in self.m)
#    1874 y = self.cv2(torch.cat(y, 1))
#    1875 if self.gamma is not None:
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:1873, in <genexpr>(.0)
#    1863 """
#    1864 Forward pass through A2C2f layer.
#    1865
#    (...)   1870     (torch.Tensor): Output tensor after processing.
#    1871 """
#    1872 y = [self.cv1(x)]
# -> 1873 y.extend(m(y[-1]) for m in self.m)
#    1874 y = self.cv2(torch.cat(y, 1))
#    1875 if self.gamma is not None:
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\PycharmProjects\AIChickenCoop\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:336, in C3.forward(self, x)
#     334 def forward(self, x):
#     335     """Forward pass through the CSP bottleneck with 3 convolutions."""
# --> 336     return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 38.00 MiB. GPU 0 has a total capacity of 8.00 GiB of which 0 bytes is free. Of the allocated memory 19.97 GiB is allocated by PyTorch, and 371.75 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
from ultralytics import YOLO

# Load a previously trained model
model = YOLO('trained_models/yolov8n/weights/best.pt')

# Recognise on an Image that it has never seen
results = model('test_difficult.png')

# Show results
results[0].show()
# Out:
# image 1/1 C:\Users\Merle\PycharmProjects\AIChickenCoop\Training\test_difficult.png: 640x384 3 birds, 60.8ms
# Speed: 2.1ms preprocess, 60.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
