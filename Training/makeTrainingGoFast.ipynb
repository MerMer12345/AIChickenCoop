# %%
import torch
print(torch.cuda.is_available())  # Should return True
print(torch.cuda.current_device())  # Should return your GPU id
print(torch.cuda.get_device_name(0))  # Check if it's your real GPU

# %%
model = model.to('cuda')
tensor = tensor.to('cuda')
