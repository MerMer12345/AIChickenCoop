# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# C:\Users\merle\PycharmProjects\OpenCVTest

# %% [markdown]
# https://media.roboflow.com/milk.zip

# %%
VIDEO_DIR_PATH = f"{HOME}/videosChickens"
IMAGE_DIR_PATH = f"{HOME}/imagesChickens"
FRAME_STRIDE = 10

# %%
import supervision as sv
from tqdm import tqdm

video_paths = sv.list_files_with_extensions(
    directory=VIDEO_DIR_PATH,
    extensions=["mov", "mp4"])
print(video_paths)
TEST_VIDEO_PATHS, TRAIN_VIDEO_PATHS = video_paths[:2], video_paths[2:]

for video_path in tqdm(TRAIN_VIDEO_PATHS):
    print(f"Saving images to {IMAGE_DIR_PATH}")
    video_name = video_path.stem
    image_name_pattern = video_name + "-{:05d}.png"
    print(f"Pattern: {image_name_pattern}")
    with sv.ImageSink(target_dir_path=IMAGE_DIR_PATH, image_name_pattern=image_name_pattern) as sink:
        for image in sv.get_video_frames_generator(source_path=str(video_path), stride=FRAME_STRIDE):
            sink.save_image(image=image)
# Out:
# [WindowsPath('C:/Users/merle/PycharmProjects/OpenCVTest/videosChickens/ChickenTest.mp4'), WindowsPath('C:/Users/merle/PycharmProjects/OpenCVTest/videosChickens/ChickenTest2.mp4'), WindowsPath('C:/Users/merle/PycharmProjects/OpenCVTest/videosChickens/ChickenTest3.mp4'), WindowsPath('C:/Users/merle/PycharmProjects/OpenCVTest/videosChickens/ChickenTest4.mp4')]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Saving images to C:\Users\merle\PycharmProjects\OpenCVTest/imagesChickens
# Pattern: ChickenTest3-{:05d}.png
#  50%|█████     | 1/2 [00:23<00:23, 23.74s/it]
# Saving images to C:\Users\merle\PycharmProjects\OpenCVTest/imagesChickens
# Pattern: ChickenTest4-{:05d}.png
# 100%|██████████| 2/2 [00:45<00:00, 22.97s/it]

# %%
import supervision as sv

image_paths = sv.list_files_with_extensions(
    directory=IMAGE_DIR_PATH,
    extensions=["png", "jpg", "jpg"])

print('image count:', len(image_paths))
# Out:
# image count: 733

# %%
IMAGE_DIR_PATH = f"{HOME}/imagesChickens"
SAMPLE_SIZE = 16
SAMPLE_GRID_SIZE = (4, 4)
SAMPLE_PLOT_SIZE = (16, 10)


import cv2
import supervision as sv

titles = [
    image_path.stem
    for image_path
    in image_paths[:SAMPLE_SIZE]]
images = [
    cv2.imread(str(image_path))
    for image_path
    in image_paths[:SAMPLE_SIZE]]

sv.plot_images_grid(images=images, titles=titles, grid_size=SAMPLE_GRID_SIZE, size=SAMPLE_PLOT_SIZE)

# %%
from autodistill.detection import CaptionOntology

ontology=CaptionOntology({
    "Chicken": "bird"
})
DATASET_DIR_PATH = f"{HOME}/datasetChickens"

# %%
from autodistill_grounded_sam import GroundedSAM

base_model = GroundedSAM(ontology=ontology)
dataset = base_model.label(
    input_folder=IMAGE_DIR_PATH,
    extension=".png",
    output_folder=DATASET_DIR_PATH)
# Out:
# Importing from timm.models.layers is deprecated, please import via timm.layers
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:3638.)
# WARNING: CUDA not available. GroundingDINO will run very slowly.
# trying to load grounding dino directly
# final text_encoder_type: bert-base-uncased
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\merle\.cache\huggingface\hub\models--bert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
# Labeling C:\Users\merle\PycharmProjects\OpenCVTest/imagesChickens\ChickenTest3-00000.png:   0%|          | 0/733 [00:00<?, ?it/s]The `device` argument is deprecated and will be removed in v5 of Transformers.
# torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
# None of the inputs have requires_grad=True. Gradients will be None
# `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# Labeling C:\Users\merle\PycharmProjects\OpenCVTest/imagesChickens\ChickenTest4-00361.png: 100%|██████████| 733/733 [3:55:37<00:00, 19.29s/it]
# Labeled dataset created - ready for distillation.

# %%
ANNOTATIONS_DIRECTORY_PATH = f"{HOME}/datasetChickens/train/labels"
IMAGES_DIRECTORY_PATH = f"{HOME}/datasetChickens/train/images"
DATA_YAML_PATH = f"{HOME}/datasetChickens/data.yaml"

# %%
import supervision as sv

dataset = sv.DetectionDataset.from_yolo(
    images_directory_path=IMAGES_DIRECTORY_PATH,
    annotations_directory_path=ANNOTATIONS_DIRECTORY_PATH,
    data_yaml_path=DATA_YAML_PATH)

len(dataset)
# Out:
# 586

# %%
import supervision as sv
from pathlib import Path


mask_annotator = sv.MaskAnnotator()
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()

images = []
image_names = []
for i, (image_path, image, annotation) in enumerate(dataset):
    if i == SAMPLE_SIZE:
        break
    annotated_image = image.copy()
    annotated_image = mask_annotator.annotate(
        scene=annotated_image, detections=annotation)
    annotated_image = box_annotator.annotate(
        scene=annotated_image, detections=annotation)
    annotated_image = label_annotator.annotate(
        scene=annotated_image, detections=annotation)

    image_names.append(Path(image_path).name)
    images.append(annotated_image)

sv.plot_images_grid(
    images=images,
    titles=image_names,
    grid_size=SAMPLE_GRID_SIZE,
    size=SAMPLE_PLOT_SIZE)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="datasetChickens/data.yaml", epochs=100, imgsz=640)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[20], line 4
#       1 from ultralytics import YOLO
#       3 # Load a model
# ----> 4 model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
#       6 # Train the model
#       7 results = model.train(data="datasetChickens/data.yaml", epochs=100, imgsz=640)
#
# File ~\PycharmProjects\OpenCVTest\.venv\Lib\site-packages\ultralytics\yolo\engine\model.py:107, in YOLO.__init__(self, model, task)
#     105     self._new(model, task)
#     106 else:
# --> 107     self._load(model, task)
#
# File ~\PycharmProjects\OpenCVTest\.venv\Lib\site-packages\ultralytics\yolo\engine\model.py:156, in YOLO._load(self, weights, task)
#     154 suffix = Path(weights).suffix
#     155 if suffix == '.pt':
# --> 156     self.model, self.ckpt = attempt_load_one_weight(weights)
#     157     self.task = self.model.args['task']
#     158     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File ~\PycharmProjects\OpenCVTest\.venv\Lib\site-packages\ultralytics\nn\tasks.py:417, in attempt_load_one_weight(weight, device, inplace, fuse)
#     415 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#     416     """Loads a single model weights."""
# --> 417     ckpt, weight = torch_safe_load(weight)  # load ckpt
#     418     args = {**DEFAULT_CFG_DICT, **ckpt['train_args']}  # combine model and default args, preferring model args
#     419     model = (ckpt.get('ema') or ckpt['model']).to(device).float()  # FP32 model
#
# File ~\PycharmProjects\OpenCVTest\.venv\Lib\site-packages\ultralytics\nn\tasks.py:357, in torch_safe_load(weight)
#     355 file = attempt_download_asset(weight)  # search online if missing locally
#     356 try:
# --> 357     return torch.load(file, map_location='cpu'), file  # load
#     358 except ModuleNotFoundError as e:  # e.name is missing module name
#     359     if e.name == 'models':
#
# File ~\PycharmProjects\OpenCVTest\.venv\Lib\site-packages\torch\serialization.py:1470, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1462                 return _load(
#    1463                     opened_zipfile,
#    1464                     map_location,
#    (...)   1467                     **pickle_load_args,
#    1468                 )
#    1469             except pickle.UnpicklingError as e:
# -> 1470                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1471         return _load(
#    1472             opened_zipfile,
#    1473             map_location,
#    (...)   1476             **pickle_load_args,
#    1477         )
#    1478 if mmap:
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.tasks.DetectionModel was not an allowed global by default. Please use `torch.serialization.add_safe_globals([DetectionModel])` or the `torch.serialization.safe_globals([DetectionModel])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
